# %%
class Person:
    pass

# %%
setattr(Person, 'name', 'Dawood')

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None,
#               'name': 'Dawood'})

# %%
type(Person)
# Out:
# type

# %%
obj = Person()

# %%
obj.name
# Out:
# 'Dawood'

# %%
obj.__dict__
# Out:
# {}

# %%
obj.name = 'Basha'

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None,
#               'name': 'Dawood'})

# %%
obj.name
# Out:
# 'Basha'

# %%
Person.name
# Out:
# 'Dawood'

# %%
Person.__name__
# Out:
# 'Person'

# %%
obj.__class__.__name__
# Out:
# 'Person'

# %%
#1 type of calling callables
print(getattr(Person, 'name'))

#2 type of calling callables
print(Person.__dict__['name'])

#3 type of calling callables
print(Person.name)
# Out:
# Dawood
# Dawood
# Dawood

# %%
#1 type of calling callables
print(getattr(obj, 'name'))

#2 type of calling callables
print(obj.__dict__['name'])

#3 type of calling callables
print(obj.name)
# Out:
# Basha
# Basha
# Basha

# %%
print(isinstance(obj, Person))
print(isinstance(Person, type))
# Out:
# True
# True

# %%
print(isinstance(obj, type.Person))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-94766de85859> in <module>
# ----> 1 print(isinstance(obj, type.Person))
#
# AttributeError: type object 'type' has no attribute 'Person'

# %%
type.__dict__
# Out:
# mappingproxy({'__repr__': <slot wrapper '__repr__' of 'type' objects>,
#               '__call__': <slot wrapper '__call__' of 'type' objects>,
#               '__getattribute__': <slot wrapper '__getattribute__' of 'type' objects>,
#               '__setattr__': <slot wrapper '__setattr__' of 'type' objects>,
#               '__delattr__': <slot wrapper '__delattr__' of 'type' objects>,
#               '__init__': <slot wrapper '__init__' of 'type' objects>,
#               '__new__': <function type.__new__(*args, **kwargs)>,
#               'mro': <method 'mro' of 'type' objects>,
#               '__subclasses__': <method '__subclasses__' of 'type' objects>,
#               '__prepare__': <method '__prepare__' of 'type' objects>,
#               '__instancecheck__': <method '__instancecheck__' of 'type' objects>,
#               '__subclasscheck__': <method '__subclasscheck__' of 'type' objects>,
#               '__dir__': <method '__dir__' of 'type' objects>,
# ...

# %%
type.__name__
# Out:
# 'type'

# %% [markdown]
# ### Data Attributes(i.e not functions)
# Data attribute is one of the callables together with functions

# %%
class MyClass:
    language = 'Python'

# %%
obj = MyClass()   # cteating instance

# %%
MyClass.language
# Out:
# 'Python'

# %%
obj.language  # here intsnce object takes the 'class attribute' i.e language from the class
# Out:
# 'Python'

# %%
# because it has different name space. when we call the attribute it searches first in its namespace i.e 'obj'
# if the attribute is not there, then it searches in class 
obj.__dict__
# Out:
# {}

# %%
obj.language = 'Java'

# %%
obj.language
# Out:
# 'Java'

# %%
obj.__dict__
# Out:
# {'language': 'Java'}

# %% [markdown]
# ### Functions attributes
#
# It is little different to data attribute

# %%
class MyClass:
    
    def say_hello():
        return f"Hello World!"

# %%
obj = MyClass()

# %%
MyClass.say_hello
# Out:
# <function __main__.MyClass.say_hello()>

# %%
obj.say_hello  # it return the memory location and method is bounded
# Out:
# <bound method MyClass.say_hello of <__main__.MyClass object at 0x0000025D275263D0>>

# %%
MyClass.say_hello()
# Out:
# 'Hello World!'

# %%
obj.say_hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-34f9cb71e8c7> in <module>
# ----> 1 obj.say_hello()
#
# TypeError: say_hello() takes 0 positional arguments but 1 was given

# %%
# in the above erroe we see that it takes positional arguments and bound to some object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hex(id(obj))
# Out:
# '0x25d275263d0'

# %%
obj.say_hello  # it is not a pure function
# Out:
# <bound method MyClass.say_hello of <__main__.MyClass object at 0x0000025D275263D0>>

# %%
type(MyClass.say_hello) # it(obj) is not a function like here
# Out:
# function

# %%
type(obj.say_hello) # for example here
# method in python; is function that is bound to an object
# Out:
# method

# %%
type(MyClass.say_hello) is type(obj.say_hello)
# Out:
# False

# %%
class Person:
    
    def say_hello(*args):
        print("say_hello args: ", args)

# %%
p = Person()

# %%
Person.say_hello() # empty args
# Out:
# say_hello args:  ()

# %%
hex(id(p))
# Out:
# '0x25d27526c40'

# %%
p.say_hello()
# Out:
# say_hello args:  (<__main__.Person object at 0x0000025D27526C40>,)

# %%
class Person:
    
    def set_name(instance_obj, new_name):
        instance_obj.name = new_name

# %%
p = Person()

# %%
p.set_name('Dawood')

# %%
p.__dict__
# Out:
# {'name': 'Dawood'}

# %%
# the above one is also equivalent to 
Person.set_name(p, 'Basha')

# %%
p.__dict__
# Out:
# {'name': 'Basha'}

# %%
p.name
# Out:
# 'Basha'
